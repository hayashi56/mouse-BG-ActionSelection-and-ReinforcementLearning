# %%
import numpy as np
import matplotlib.pyplot as plt

synapsepotentialdata_file_MSND1 = 'MSN_D1firingrate.dat'
synapsepotentialdata_file_MSND2 = 'MSN_D2firingrate.dat'
data_file_MSND1 = 'MSN_D1.dat'
data_file_MSND2 = 'MSN_D2.dat'
alpha_data_file_FSI = 'FSI.dat'
alpha_data_file_STN = 'STN.dat'
alpha_data_file_GPe = 'GPe.dat'
alpha_data_file_SNc = 'SNc.dat'
alpha_data_file_PTN = 'PTN.dat'
alpha_data_file_CMPf = 'CMPf.dat'
alpha_data_file_PSA = 'PSN.dat'
alpha_data_file_MSND1 = 'MSN_D1_debag.dat'
alpha_data_file_MSND2 = 'MSN_D2_debag.dat'
synapsepotentialdata_file_FSI = 'FSIfiringrate.dat'
synapsepotentialdata_file_STN = 'STNfiringrate.dat'
synapsepotentialdata_file_GPe = 'GPefiringrate.dat'
synapsepotentialdata_file_GPi = 'GPifiringrate.dat'
synapsepotentialdata_file_SNc = 'SNcfiringrate.dat'
synapsepotentialdata_file_PTN = 'PTNfiringrate.dat'
synapsepotentialdata_file_PTI = 'PTIfiringrate.dat'
synapsepotentialdata_file_Th = 'Thfiringrate.dat'
synapsepotentialdata_file_CMPf = 'CMPffiringrate.dat'
synapsepotentialdata_file_PSA = 'PSNfiringrate.dat'
MSND1potential = np.loadtxt(data_file_MSND1)
MSND2potential = np.loadtxt(data_file_MSND2)
MSND1synapsepotential = np.loadtxt(synapsepotentialdata_file_MSND1)
MSND2synapsepotential = np.loadtxt(synapsepotentialdata_file_MSND2)
FSIsynapsepotential = np.loadtxt(synapsepotentialdata_file_FSI)
STNsynapsepotential = np.loadtxt(synapsepotentialdata_file_STN)
GPesynapsepotential = np.loadtxt(synapsepotentialdata_file_GPe)
GPisynapsepotential = np.loadtxt(synapsepotentialdata_file_GPi)
SNcsynapsepotential = np.loadtxt(synapsepotentialdata_file_SNc)
PTNsynapsepotential = np.loadtxt(synapsepotentialdata_file_PTN)
PTIsynapsepotential = np.loadtxt(synapsepotentialdata_file_PTI)
Thsynapsepotential = np.loadtxt(synapsepotentialdata_file_Th)
CMPfsynapsepotential = np.loadtxt(synapsepotentialdata_file_CMPf)
PSAsynapsepotential = np.loadtxt(synapsepotentialdata_file_PSA)
MSND1_alpha = np.loadtxt(alpha_data_file_MSND1)
MSND2_alpha = np.loadtxt(alpha_data_file_MSND2)
FSI_alpha = np.loadtxt(alpha_data_file_FSI)
STN_alpha = np.loadtxt(alpha_data_file_STN)
GPe_alpha = np.loadtxt(alpha_data_file_GPe)
SNc_alpha = np.loadtxt(alpha_data_file_SNc)
PTN_alpha = np.loadtxt(alpha_data_file_PTN)
PSA_alpha = np.loadtxt(alpha_data_file_PSA)
CMPf_alpha = np.loadtxt(alpha_data_file_CMPf)

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1_alpha[:,0], MSND1_alpha[:,1], label = "MSND1" )
plt.plot( MSND2_alpha[:,0], MSND2_alpha[:,1], label = "MSND2" )
plt.plot( FSI_alpha[:,0], FSI_alpha[:,1], label = "FSI" )
plt.plot( STN_alpha[:,0], STN_alpha[:,1], label = "STN" )
plt.plot( GPe_alpha[:,0], GPe_alpha[:,1], label = "GPe" )
plt.plot( SNc_alpha[:,0], SNc_alpha[:,1], label = "SNc" )
plt.plot( PTN_alpha[:,0], PTN_alpha[:,1], label = "PTN" )
plt.plot( PSA_alpha[:,0], PSA_alpha[:,1], label = "PSA" )
plt.plot( CMPf_alpha[:,0], CMPf_alpha[:,1], label = "CMPf" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1_alpha[:,0], MSND1_alpha[:,1], label = "MSND1" )
plt.plot( MSND2_alpha[:,0], MSND2_alpha[:,1], label = "MSND2" )
plt.plot( FSI_alpha[:,0], FSI_alpha[:,1], label = "FSI" )
plt.plot( GPe_alpha[:,0], GPe_alpha[:,1], label = "GPe" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
plt.xlim([900,1000])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( STN_alpha[:,0], STN_alpha[:,1], label = "STN" )
plt.plot( PTN_alpha[:,0], PTN_alpha[:,1], label = "PTN" )
plt.plot( PSA_alpha[:,0], PSA_alpha[:,1], label = "PSA" )
plt.plot( CMPf_alpha[:,0], CMPf_alpha[:,1], label = "CMPf" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
plt.xlim([800,1000])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1_alpha[:,0], MSND1_alpha[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND2_alpha[:,0], MSND2_alpha[:,1], label = "MSND2" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( FSI_alpha[:,0], FSI_alpha[:,1], label = "FSI" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( STN_alpha[:,0], STN_alpha[:,1], label = "STN" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( GPe_alpha[:,0], GPe_alpha[:,1], label = "GPe" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( SNc_alpha[:,0], SNc_alpha[:,1], label = "SNc" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( PTN_alpha[:,0], PTN_alpha[:,1], label = "PTN" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( PSA_alpha[:,0], PSA_alpha[:,1], label = "PSA" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( CMPf_alpha[:,0], CMPf_alpha[:,1], label = "CMPf" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1potential[:,0], MSND1potential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
plt.xlim([800,1000])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND2potential[:,0], MSND2potential[:,1], label = "MSND2" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
plt.xlim([800,1000])
#plt.ylim([-80,0])
#plt.xlim([-5,10])
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

data_file_MSND1 = 'MSN_D1.dat'
data_file_MSND2 = 'MSN_D2.dat'

MSND1potential = np.loadtxt(data_file_MSND1)
MSND2potential = np.loadtxt(data_file_MSND2)

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1potential[:,0], MSND1potential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
plt.xlim([800,1000])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND2potential[:,0], MSND2potential[:,1], label = "MSND2" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
plt.xlim([800,1000])
#plt.ylim([-80,0])
#plt.xlim([-5,10])
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

data_file_MSND1 = 'MSN_D1.dat'
data_file_MSND2 = 'MSN_D2.dat'

MSND1potential = np.loadtxt(data_file_MSND1)
MSND2potential = np.loadtxt(data_file_MSND2)

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1potential[:,0], MSND1potential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([800,1000])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND2potential[:,0], MSND2potential[:,1], label = "MSND2" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
plt.xlim([800,1000])
#plt.ylim([-80,0])
#plt.xlim([-5,10])
plt.legend()

# %%
# xx: 1次元のnumpy.array
n_conv = 50

b = np.ones(n_conv)/n_conv 
# >> [1/n_size, 1/n_size, ..., 1/n_size]

MSND1firingrate_mean = np.convolve(MSND1synapsepotential[:,1], b, mode="same")
MSND2firingrate_mean = np.convolve(MSND2synapsepotential[:,1], b, mode="same")
FSIfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
STNfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
GPefiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
GPifiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
SNcfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
PTNfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
PTIfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
PSNfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
PTNfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")
PTNfiringrate_mean = np.convolve(SNcsynapsepotential[:,1], b, mode="same")

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1synapsepotential[:,0], MSND1synapsepotential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND2synapsepotential[:,0], MSND2synapsepotential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( FSIsynapsepotential[:,0], FSIsynapsepotential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( STNsynapsepotential[:,0], STNsynapsepotential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( GPesynapsepotential[:,0], GPesynapsepotential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( GPisynapsepotential[:,0], GPisynapsepotential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( SNcsynapsepotential[:,0], SNcsynapsepotential[:,1], label = "MSND1" )
plt.ylabel("potentail[mV]")
plt.xlabel("time[ms]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
plt.plot( PTIsynapsepotential[:,0], PTIsynapsepotential[:,1], label = "PTI" )
plt.plot( PTNsynapsepotential[:,0], PTNsynapsepotential[:,1], label = "PTN" )
plt.plot( Thsynapsepotential[:,0], Thsynapsepotential[:,1], label = "Th" )
plt.plot( CMPfsynapsepotential[:,0], CMPfsynapsepotential[:,1], label = "CMPf" )
plt.plot( PSAsynapsepotential[:,0], PSAsynapsepotential[:,1], label = "PSA" )
plt.xlabel("time [ms]")
plt.ylabel("potentail[mV]")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()
