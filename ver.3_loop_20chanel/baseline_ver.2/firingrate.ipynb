# %%
import numpy as np
import matplotlib.pyplot as plt

synapsepotentialdata_file_MSND1 = 'MSN_D1firingrate.dat'
synapsepotentialdata_file_MSND2 = 'MSN_D2firingrate.dat'
synapsepotentialdata_file_FSI = 'FSIfiringrate.dat'
synapsepotentialdata_file_STN = 'STNfiringrate.dat'
synapsepotentialdata_file_GPe = 'GPefiringrate.dat'
synapsepotentialdata_file_GPi = 'GPifiringrate.dat'
synapsepotentialdata_file_SNc = 'SNcfiringrate.dat'
synapsepotentialdata_file_PTN = 'PTNfiringrate.dat'
synapsepotentialdata_file_PTI = 'PTIfiringrate.dat'
synapsepotentialdata_file_Th = 'Thfiringrate.dat'
synapsepotentialdata_file_CMPf = 'CMPffiringrate.dat'
synapsepotentialdata_file_PSN = 'PSNfiringrate.dat'
data_file_SNc = 'SNc.dat'
data_file_PTN = 'PTN.dat'
data_file_PSN = 'PSN.dat'
adata_file_PTN = 'PTNdebag.dat'
MSND1synapsepotential = np.loadtxt(synapsepotentialdata_file_MSND1)
MSND2synapsepotential = np.loadtxt(synapsepotentialdata_file_MSND2)
FSIsynapsepotential = np.loadtxt(synapsepotentialdata_file_FSI)
STNsynapsepotential = np.loadtxt(synapsepotentialdata_file_STN)
GPesynapsepotential = np.loadtxt(synapsepotentialdata_file_GPe)
GPisynapsepotential = np.loadtxt(synapsepotentialdata_file_GPi)
SNcsynapsepotential = np.loadtxt(synapsepotentialdata_file_SNc)
PTNsynapsepotential = np.loadtxt(synapsepotentialdata_file_PTN)
SNc = np.loadtxt(data_file_SNc)
PTN = np.loadtxt(data_file_PTN)
PSN = np.loadtxt(data_file_PSN)
aPTN = np.loadtxt(adata_file_PTN)
PTIsynapsepotential = np.loadtxt(synapsepotentialdata_file_PTI)
Thsynapsepotential = np.loadtxt(synapsepotentialdata_file_Th)
CMPfsynapsepotential = np.loadtxt(synapsepotentialdata_file_CMPf)
PSNsynapsepotential = np.loadtxt(synapsepotentialdata_file_PSN)

# %%
plt.figure(figsize=(20,7))
plt.plot( SNc[:,0], SNc[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([600,700])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( PTN[:,0], PTN[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([600,700])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( aPTN[:,0], aPTN[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( PSN[:,0], PSN[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([700,1000])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND1synapsepotential[:,0], MSND1synapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( MSND2synapsepotential[:,0], MSND2synapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( FSIsynapsepotential[:,0], FSIsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( STNsynapsepotential[:,0], STNsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( GPesynapsepotential[:,0], GPesynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( GPisynapsepotential[:,0], GPisynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( SNcsynapsepotential[:,0], SNcsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( PTNsynapsepotential[:,0], PTNsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( PTIsynapsepotential[:,0], PTIsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( PSNsynapsepotential[:,0], PSNsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( Thsynapsepotential[:,0], Thsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')

# %%
plt.figure(figsize=(20,7))
plt.plot( CMPfsynapsepotential[:,0], CMPfsynapsepotential[:,1])
plt.xlabel("t [ms]")
plt.ylabel("firingrate")
#plt.ylim([-2,3])
#plt.xlim([-5,10])
# Out:
# Text(0, 0.5, 'firingrate')
