# %%
import numpy as np
import matplotlib.pyplot as plt

#synapsepotentialdata_file_MSND1 = 'MSN_D1.dat'
#synapsepotentialdata_file_MSND2 = 'MSN_D2.dat'
#synapsepotentialdata_file_FSI = 'FSI.dat'
#synapsepotentialdata_file_STN = 'STN.dat'
#synapsepotentialdata_file_GPe = 'GPe.dat'
#synapsepotentialdata_file_GPi = 'GPi.dat'
#synapsepotentialdata_file_PTN = 'PTN.dat'
#synapsepotentialdata_file_PTI = 'PTI.dat'
synapsepotentialdata_file_Th = 'Th.dat'
potentialdata_file_Th = 'Thdebag.dat'
synapsepotentialdata_file_CMPf = 'CMPf.dat'
potentialdata_file_CMPf = 'CMPfdebag.dat'
synapsepotentialdata_file_PSA = 'PSA.dat'
potentialdata_file_PSA = 'PSAdebag.dat'
#MSND1synapsepotential = np.loadtxt(synapsepotentialdata_file_MSND1)
#MSND2synapsepotential = np.loadtxt(synapsepotentialdata_file_MSND2)
#FSIsynapsepotential = np.loadtxt(synapsepotentialdata_file_FSI)
#STNsynapsepotential = np.loadtxt(synapsepotentialdata_file_STN)
#GPesynapsepotential = np.loadtxt(synapsepotentialdata_file_GPe)
#GPisynapsepotential = np.loadtxt(synapsepotentialdata_file_GPi)
#PTNsynapsepotential = np.loadtxt(synapsepotentialdata_file_PTN)
#PTIsynapsepotential = np.loadtxt(synapsepotentialdata_file_PTI)
Thsynapsepotential = np.loadtxt(synapsepotentialdata_file_Th)
Thpotential = np.loadtxt(potentialdata_file_Th)
CMPfsynapsepotential = np.loadtxt(synapsepotentialdata_file_CMPf)
CMPfpotential = np.loadtxt(potentialdata_file_CMPf)
PSAsynapsepotential = np.loadtxt(synapsepotentialdata_file_PSA)
PSApotential = np.loadtxt(potentialdata_file_PSA)

# %%
plt.figure(figsize=(20,7))
#plt.plot( PTIsynapsepotential[:,0], PTIsynapsepotential[:,1], label = "PTI" )
#plt.plot( PTNsynapsepotential[:,0], PTNsynapsepotential[:,1], label = "PTN" )
plt.plot( Thsynapsepotential[:,0], Thsynapsepotential[:,1], label = "Th0" )
plt.plot( CMPfsynapsepotential[:,0], CMPfsynapsepotential[:,1], label = "Th1" )
plt.plot( PSAsynapsepotential[:,0], PSAsynapsepotential[:,1], label = "Th2" )
plt.xlabel("t [ms]")
plt.ylabel("potentail[mV]")
plt.ylim([-2,3])
#plt.xlim([-5,10])
plt.legend()

# %%
plt.figure(figsize=(20,7))
#plt.plot( PTNsynapsepotential[:,0], PTNsynapsepotential[:,1], label = "PTN" )
#plt.plot( MSND1synapsepotential[:,0], MSND1synapsepotential[:,1], label = "MSND1" )
#plt.plot( MSND2synapsepotential[:,0], MSND2synapsepotential[:,1], label = "MSND2" )
#plt.plot( FSIsynapsepotential[:,0], FSIsynapsepotential[:,1], label = "FSI" )
#plt.plot( STNsynapsepotential[:,0], STNsynapsepotential[:,1], label = "STN" )
#plt.plot( GPesynapsepotential[:,0], GPesynapsepotential[:,1], label = "GPe" )
#plt.plot( GPisynapsepotential[:,0], GPisynapsepotential[:,1], label = "GPi" )
plt.plot( Thpotential[:,0], Thpotential[:,1], label = "Th0" )
#plt.plot( CMPfpotential[:,0], CMPfpotential[:,1], label = "Th1" )
#plt.plot( PSApotential[:,0], PSApotential[:,1], label = "Th2" )
plt.xlabel("t [ms]")
plt.ylabel("potentail[mV]")
plt.legend()

# %%
plt.figure(figsize=(20,7))
#plt.plot( MSND1synapsepotential[:,0], MSND1synapsepotential[:,1], label = "MSND1" )
#plt.plot( MSND2synapsepotential[:,0], MSND2synapsepotential[:,1], label = "MSND2" )
#plt.plot( FSIsynapsepotential[:,0], FSIsynapsepotential[:,1], label = "FSI" )
#plt.plot( STNsynapsepotential[:,0], STNsynapsepotential[:,1], label = "STN" )
#plt.plot( GPesynapsepotential[:,0], GPesynapsepotential[:,1], label = "GPe" )
#plt.plot( GPisynapsepotential[:,0], GPisynapsepotential[:,1], label = "GPi" )
plt.plot( Thsynapsepotential[:,0], Thsynapsepotential[:,1], label = "Th" )
plt.xlabel("t [ms]")
plt.ylabel("potentail[mV]")
plt.legend()
##plt.ylim([0,50])
##plt.xlim([0,100])
